# %%
# Initialize Otter
import otter
grader = otter.Notebook("lab.ipynb")

# %% [markdown]
# # Lab 0 - Getting Set Up

# %% [markdown]
# ## Instructions
#
# Welcome to DSC 259R! The goal of this Lab 0 is to make sure that your Python environment is set up for the course. There are no content-related coding questions in this lab, but if you are able to complete this assignment, then you will be ready to start working on Lab 1 (and the remainder of this course).
#
# In DSC 259R, we will emulate a standard workflow in industry where exploration is done in Jupyter notebooks (`.ipynb` files) and production code is copied into a normal Python files (`.py` files). Notice that this file is a notebook (`lab.ipynb`) and there is also a `lab.py` file in the same parent folder of this notebook. For this lab (and future assignments), the coding will be done in an accompanying `lab.py` file that is imported into the current notebook, and **you will only submit that `lab.py` file**, not this notebook!
#
# Some additional guidelines:
# - **Future labs will have both public tests and hidden tests.** The bulk of your grade will come from your scores on hidden tests, which you will only see on Gradescope after the assignment deadline.
# - **Do not change the function names in the `lab.py` file!** The functions in the `lab.py` file are how your assignment is graded, and they are graded by their name. If you changed something you weren't supposed to, you can find the original code in the course GitHub repository.
# - Notebooks are nice for testing and experimenting with different implementations before designing your function in your `lab.py` file. You can write code here, but make sure that all of your real work is in the `lab.py` file, since that's all you're submitting.
# - You are encouraged to write your own additional helper functions to solve the lab, as long as they also end up in `lab.py`.
#
# **To ensure that all of the work you want to submit is in `lab.py`, we've included a script named `lab-validation.py` in the lab folder. You shouldn't edit it, but instead, you should call it from the command line (e.g. the Terminal) to test your work.** More details on its usage are given at the bottom of this notebook.

# %% [markdown]
# **Importing code from `lab.py`**:
#
# * Below, we import the `.py` file that's contained in the same directory as this notebook.
# * We use the `autoreload` notebook extension to make changes to our `lab.py` file immediately available in our notebook. Without this extension, we would need to restart the notebook kernel to see any changes to `lab.py` in the notebook.
#     - `autoreload` is necessary because, upon import, `lab.py` is compiled to bytecode (in the directory `__pycache__`). Subsequent imports of `lab` merely import the existing compiled python.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from lab import *

# %%
from pathlib import Path
import io
import pandas as pd
import numpy as np
np.set_printoptions(legacy='1.21')

# %% [markdown]
# ### Question 0 – Checking your environment
#
# Copy the code below into the `env_check` function in `lab.py`. Then, run the autograder tests to check that your package versions match the ones we're using for the course. If you get an error in this step, please double check that you have followed all the instructions on the Tech Support page of the course.
#
# ```python
# def env_check():
#     import pandas as pd
#     import otter
#     import sklearn
#     print(f'pandas: {pd.__version__}')
#     print(f'otter: {otter.__version__}')
#     print(f'scikit-learn: {sklearn.__version__}')
# ```

# %%
# The cells below are here for you to write scratch work in. 
# You should write the code for your answer in `lab.py`, not here, but you can
# call your env_check function see its output and make sure it works.
# For example:

# %%
env_check()
# Out:
# pandas: 2.2.3
# otter: 6.1.6
# scikit-learn: 1.5.2

# %% [markdown]
# To run the public tests on your code for a given question, run the cell containing a call to `grader.check` that immediately follows it.
#
# You can write custom tests either by calling your functions on different inputs here in the notebook, or by writing doctests in `lab.py`.

# %%
grader.check("q0")
# Out:
# q0 results: All test cases passed!

# %% [markdown]
# ## Congratulations! You're done with Lab 0! 🏁
#
# As a reminder, all of the work you want to submit needs to be in `lab.py`.
#
# To ensure that all of the work you want to submit is in `lab.py`, we've included a script named `lab-validation.py` in the lab folder. You shouldn't edit it, but instead, you should call it from the command line (e.g. the Terminal) to test your work.
#
# Once you've finished the lab, you should open the command line and run, in the directory for this lab:
#
# ```
# python lab-validation.py
# ```
#
# **This will run all of the `grader.check` cells that you see in this notebook, but only using the code in `lab.py` – that is, it doesn't look at any of the code in this notebook. If all of your `grader.check` cells pass in this notebook but not all of them pass in your command line with the above command, then you likely have code in your notebook that isn't in your `lab.py`!**
#
# Once `python lab-validation.py` shows that you're passing all test cases, you're ready to submit your `lab.py` (and only your `lab.py`) to Gradescope. Once submitting to Gradescope, make sure to stick around until all test cases pass.
